# %% [markdown]
# Neural Style Transfer
#
# paper: [Gatys et al. A Neural algorithm for artistic style. 2015.](https://arxiv.org/pdf/1508.06576.pdf)
#
# Based on code [style-transfer-pytorch](https://github.com/crowsonkb/style-transfer-pytorch)
#
# Source: [style-transfer](https://github.com/olaviinha/style-transfer-pytorch)
#
# Author: [@olaviinha](https://github.com/olaviinha)

# %%
# !git clone https://github.com/olaviinha/style-transfer-pytorch
# !pip install -e ./style-transfer-pytorch
# Out:
# Cloning into 'style-transfer-pytorch'...
# remote: Enumerating objects: 606, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 606 (delta 225), reused 215 (delta 215), pack-reused 374
# Receiving objects: 100% (606/606), 2.73 MiB | 13.64 MiB/s, done.
# Resolving deltas: 100% (387/387), done.
# Obtaining file:///content/style-transfer-pytorch
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for style-transfer-pytorch
# ...

# %%
import IPython
import os

# %%
# !wget https://images.metmuseum.org/CRDImages/ep/original/DT1567.jpg
# !wget https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/i/e6b44614-3be2-44bb-af8b-ae8449bf1690/dg4x6da-292bf848-91b9-4d08-90c8-5a81267fb550.jpg/v1/fill/w_1192,h_670,q_70,strp/windows_xp_and_7_wallpapers__3840x2160__by_simurated_dg4x6da-pre.jpg
# Out:
# --2024-02-21 13:45:07--  https://images.metmuseum.org/CRDImages/ep/original/DT1567.jpg
# Resolving images.metmuseum.org (images.metmuseum.org)... 45.60.77.20
# Connecting to images.metmuseum.org (images.metmuseum.org)|45.60.77.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4127967 (3.9M) [image/jpeg]
# Saving to: ‘DT1567.jpg’
#
# DT1567.jpg          100%[===================>]   3.94M  --.-KB/s    in 0.09s
#
# 2024-02-21 13:45:07 (42.1 MB/s) - ‘DT1567.jpg’ saved [4127967/4127967]
#
# --2024-02-21 13:45:08--  https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/i/e6b44614-3be2-44bb-af8b-ae8449bf1690/dg4x6da-292bf848-91b9-4d08-90c8-5a81267fb550.jpg/v1/fill/w_1192,h_670,q_70,strp/windows_xp_and_7_wallpapers__3840x2160__by_simurated_dg4x6da-pre.jpg
# Resolving images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com (images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com)... 65.8.49.42, 65.8.49.18, 65.8.49.66, ...
# ...

# %%
content_image = f"{os.getcwd()}/windows_xp_and_7_wallpapers__3840x2160__by_simurated_dg4x6da-pre.jpg"
style_image   = f"{os.getcwd()}/DT1567.jpg"
output_image  = f"{os.getcwd()}/output.jpg"

# !style_transfer "{content_image}" "{style_image}" --output "{output_image}" --save-every 50 --min-scale 1024 --style-scale-fac 8.08

#IPython.display.Image(content_image)
#IPython.display.Image(style_image)
IPython.display.Image(output_image)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:03<00:00, 154MB/s]
# 100% 1000/1000 [00:53<00:00, 18.63it/s]
