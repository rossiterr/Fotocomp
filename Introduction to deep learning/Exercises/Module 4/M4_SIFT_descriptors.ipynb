# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/TIC-13/luxai_fotografia_computacional_rscs.git

# !unzip luxai_fotografia_computacional_rscs/data.zip -d .
# Out:
# fatal: destination path 'luxai_fotografia_computacional_rscs' already exists and is not an empty directory.
# Archive:  luxai_fotografia_computacional_rscs/data.zip
#    creating: ./data/
#   inflating: ./data/cat1.jpg
#   inflating: ./data/cat2.jpg
#   inflating: ./data/cat3.jpg
#   inflating: ./data/cat4.jpg

# %%
image = cv2.imread("./data/cat1.jpg")

gray  = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, desc   = sift.detectAndCompute(gray, None)

img_sift = image.copy()
img_sift = cv2.drawKeypoints(gray, kp, img_sift)

plt.imshow(img_sift)
plt.show()

# %%
image2 = cv2.imread('./data/cat2.jpg')
image3 = cv2.imread('./data/cat3.jpg')

gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray2)
plt.show()

# %%
plt.imshow(gray3)
plt.show()

# %%
kp2, desc2 = sift.detectAndCompute(gray2, None)
kp3, desc3 = sift.detectAndCompute(gray3, None)

bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches12 = bf.match(desc, desc2)
matches13 = bf.match(desc, desc3)

matches12 = sorted(matches12, key=lambda x: x.distance)
matches13 = sorted(matches13, key=lambda x: x.distance)

# %%
img_sift2 = image2.copy()
img_sift2 = cv2.drawMatches(gray, kp, gray2, kp2, matches12[:50], img_sift2, flags=2)

plt.imshow(img_sift2)
plt.show()

# %%
img_sift3 = image3.copy()
img_sift3 = cv2.drawMatches(gray, kp, gray3, kp3, matches13[:50], img_sift3, flags=2)

plt.imshow(img_sift3)
plt.show()
